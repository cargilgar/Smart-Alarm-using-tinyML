# %%
import pandas as pd

# %%
df = pd.read_csv("./hchs-sol-sueno-00163225.csv")

df.head(20)
# Out:
#        pid  sawa2  line  offwrist  activity  marker  whitelight  redlight  \
# 0   163225      1     1         0       129       0       44.34     4.950
# 1   163225      1     2         0       271       0       71.93     4.340
# 2   163225      1     3         0       171       0       61.29     4.160
# 3   163225      1     4         0       281       0       36.23     1.910
# 4   163225      1     5         0       365       0       18.07     2.760
# 5   163225      1     6         0       143       0      334.96    22.500
# 6   163225      1     7         0       134       0      187.66    15.600
# 7   163225      1     8         0       188       0      139.66     4.840
# 8   163225      1     9         0       271       0       81.11     2.820
# 9   163225      1    10         0       148       0        3.53     0.272
# 10  163225      1    11         0       247       0        2.42     0.090
# 11  163225      1    12         0       341       0       55.05     2.470
# ...
